# %%
import numpy as np
from movingfp.gen import erdos_connected, draw_mfp

# %%
n = 20
p = 0.25
dim = 2
fighter_pos = None
num_fires = 1
seed = 6845406670007309403110730420044295152
generator = np.random.default_rng(seed)

instance = erdos_connected(n, p, dim, fighter_pos, num_fires, generator)

draw_mfp(instance)

# %%
n = 20
p = 0.25
dim = 2
fighter_pos = None
num_fires = 2
seed = 6845406670007309403110730420044295152
generator = np.random.default_rng(seed)

instance = erdos_connected(n, p, dim, fighter_pos, num_fires, generator)

draw_mfp(instance)

# %%
n = 20
p = 0.25
dim = 2
fighter_pos = None
num_fires = 3
seed = 6845406670007309403110730420044295152
generator = np.random.default_rng(seed)

instance = erdos_connected(n, p, dim, fighter_pos, num_fires, generator)

draw_mfp(instance)

# %%
n = 20
p = 0.25
dim = 2
fighter_pos = None
num_fires = 4
seed = 6845406670007309403110730420044295152
generator = np.random.default_rng(seed)

instance = erdos_connected(n, p, dim, fighter_pos, num_fires, generator)

draw_mfp(instance)

# %%
import numpy as np

seed = 6845406670007309403110730420044295152
ss = np.random.SeedSequence(seed)

# A seed sequence for each experiment, e.g.: 20 nodes, 1 init fire and 10 seeds. 
ss_exp = ss.spawn(10)

# 10 generator, each generator with 1 different seed
ss_runs = ss_exp[0].spawn(10)
rng = [np.random.default_rng(s) for s in ss_runs]

instance = erdos_connected(n, p, dim, fighter_pos, num_fires, generator)
